# %%
library(wordcloud)
# Out:
# Loading required package: RColorBrewer

# %%
words <- read.csv(file = "output", sep = "\t", header = FALSE)

# %%
names(words) <- c("Word","Frequency")

# %%
wordcloud(words = words$Word, freq = words$Frequency, colors = brewer.pal(8,"Dark2"))
# Out:
# plot without title
